# %% [markdown]
# #### <div style="color:#0077b6; text-align:right">NAME : SANJHI JAIN</div>
# #### <div style="color:#0077b6; text-align:right">ROLL NO : CSC/21/19</div>

# %% [markdown]
# ## <span style="color:#4a4e69">PRACTICAL 04 </span>

# %% [markdown]
# #### <span style="color:#007f5f">4.Consider two excel files having attendance of a workshop’s participants for two days. Each file has three fields , Name ,Time of Joining , duration(in minutes) Where names are unique within a file . Note that duuration may take one of three values (30,40,50) only.Import the data into two dataframes and do the following:</span>

# %%
# importing pandas library
# importing numpy library

import pandas as pd
import numpy as np
import openpyxl as op
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 import pandas as pd
#       5 import numpy as np
# ----> 6 import openpyxl as op
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
#loading dataset into dataframe
file1='Day1.xlsx'
file2='Day2.xlsx'

df1=pd.read_excel(file1)
df2=pd.read_excel(file2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\_optional.py:132, in import_optional_dependency(name, extra, errors, min_version)
#     131 try:
# --> 132     module = importlib.import_module(name)
#     133 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 5
#       2 file1='Day1.xlsx'
#       3 file2='Day2.xlsx'
# ----> 5 df1=pd.read_excel(file1)
#       6 df2=pd.read_excel(file2)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1580, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1577 self.engine = engine
#    1578 self.storage_options = storage_options
# -> 1580 self._reader = self._engines[engine](
#    1581     self._io,
#    1582     storage_options=storage_options,
#    1583     engine_kwargs=engine_kwargs,
#    1584 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)
#     539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)
#     550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     133 except ImportError:
#     134     if errors == "raise":
# --> 135         raise ImportError(msg)
#     136     return None
#     138 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
df1
# Out:
#                   Name Time of Joining  Duration
# 0        Joseph Harris        12:15:00        50
# 1       Jessica Martin        12:30:00        50
# 2      Thomas Thompson        12:45:00        40
# 3         Sarah Garcia        13:00:00        50
# 4     Charles Martinez        13:15:00        30
# 5        Lisa Robinson        13:30:00        50
# 6    Christopher Clark        13:45:00        40
# 7     Daniel Rodriguez        14:00:00        50
# 8           Mary Lewis        14:15:00        50
# 9         Patricia Lee        14:30:00        40
# 10         Mark Walker        14:45:00        40
# 11      Elizabeth Hall        15:00:00        30
# 12        Robert Allen        15:15:00        50
# 13         James Young        15:30:00        40
# 14  Jennifer Hernandez        15:45:00        50
# 15        Michael King        16:00:00        40
# 16      William Wright        16:15:00        50

# %%
df2
# Out:
#                   Name Time of Joining  Duration
# 0             John Doe        09:00:00        40
# 1           Jane Smith        09:15:00        30
# 2       Robert Johnson        09:30:00        50
# 3          James Brown        09:45:00        30
# 4       Patricia Davis        10:00:00        50
# 5       Michael Miller        10:15:00        40
# 6         Linda Wilson        10:30:00        50
# 7          Mark Walker        10:45:00        50
# 8       Elizabeth Hall        11:00:00        30
# 9         Robert Allen        11:15:00        40
# 10         James Young        11:30:00        50
# 11  Jennifer Hernandez        11:45:00        40
# 12        Michael King        12:00:00        50
# 13      William Wright        12:15:00        50

# %% [markdown]
# ##### <span style="color:#003f88">a. Perform merging of the two dataframes to find the names of students who had attended the workshop on both days</span>

# %%
#extracting common attendees
both_day=pd.merge(df1,df2,on='Name',how='inner')
print("Common Attendees : \n")
both_day
# Out:
# Common Attendees :
#                  Name Time of Joining_x  Duration_x Time of Joining_y  \
# 0         Mark Walker          14:45:00          40          10:45:00
# 1      Elizabeth Hall          15:00:00          30          11:00:00
# 2        Robert Allen          15:15:00          50          11:15:00
# 3         James Young          15:30:00          40          11:30:00
# 4  Jennifer Hernandez          15:45:00          50          11:45:00
# 5        Michael King          16:00:00          40          12:00:00
# 6      William Wright          16:15:00          50          12:15:00
#
#    Duration_y
# 0          50
# 1          30
# 2          40
# 3          50
# 4          40
# 5          50
# 6          50

# %% [markdown]
# ##### <span style="color:#003f88">b. Find names of all students who have attended workshop on either of the days.</span>

# %%
attendees = pd.concat([df1,df2]).drop_duplicates(subset='Name')
print("Total Attendees\n")
attendees
# Out:
# Total Attendees
#                   Name Time of Joining  Duration
# 0        Joseph Harris        12:15:00        50
# 1       Jessica Martin        12:30:00        50
# 2      Thomas Thompson        12:45:00        40
# 3         Sarah Garcia        13:00:00        50
# 4     Charles Martinez        13:15:00        30
# 5        Lisa Robinson        13:30:00        50
# 6    Christopher Clark        13:45:00        40
# 7     Daniel Rodriguez        14:00:00        50
# 8           Mary Lewis        14:15:00        50
# 9         Patricia Lee        14:30:00        40
# 10         Mark Walker        14:45:00        40
# 11      Elizabeth Hall        15:00:00        30
# 12        Robert Allen        15:15:00        50
# 13         James Young        15:30:00        40
# 14  Jennifer Hernandez        15:45:00        50
# 15        Michael King        16:00:00        40
# 16      William Wright        16:15:00        50
# 0             John Doe        09:00:00        40
# 1           Jane Smith        09:15:00        30
# 2       Robert Johnson        09:30:00        50
# 3          James Brown        09:45:00        30
# 4       Patricia Davis        10:00:00        50
# 5       Michael Miller        10:15:00        40
# 6         Linda Wilson        10:30:00        50

# %% [markdown]
# ##### <span style="color:#003f88">c. Merge two data frames row-wise and find the total number of records in the data frame</span>

# %%
merged_df=pd.concat([df1,df2])
print("Total number of records:\n")
len(merged_df)
# Out:
# Total number of records:
# 31

# %% [markdown]
# ##### <span style="color:#003f88">d. Merge two data frames and use two columns names and duration as multi-row indexes. Generate descriptive statistic for this multi-index.</span>

# %%
df3=pd.merge(df1,df2,on=['Name','Duration'],how='inner')
df3

statics=df3.groupby(['Name','Duration']).describe()
print("Descriptive statistic:\n")
statics
# Out:
# Descriptive statistic:
#                         Time of Joining_x                        \
#                                     count unique       top freq
# Name           Duration
# Elizabeth Hall 30                       1      1  15:00:00    1
# William Wright 50                       1      1  16:15:00    1
#
#                         Time of Joining_y
#                                     count unique       top freq
# Name           Duration
# Elizabeth Hall 30                       1      1  11:00:00    1
# William Wright 50                       1      1  12:15:00    1
